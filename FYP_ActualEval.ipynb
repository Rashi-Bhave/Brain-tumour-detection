# %%
import FYP_modeleval
import numpy as np

# %%
testing_x_location = "/Users/sumitkhare/testing_x.npy"
testing_y_location = "/Users/sumitkhare/testing_y.npy"

Custom_Model_Location = '/Users/sumitkhare/custom'
Custom_Training_History = "/Users/sumitkhare/custom_model_history_5epoch.npy"

# %%
testing_x, testing_y = FYP_modeleval.loadTestingData(testing_x_location, testing_y_location)

# %%
custom_predictions = FYP_modeleval.generatePredictions(Custom_Model_Location, testing_x)
# Out:
# 2022-11-28 14:42:50.438345: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-28 14:43:16.337045: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: /Users/sumitkhare/custom loaded successfully
# 38/38 [==============================] - 118s 3s/step

# %%
custom_class_report_Multi = FYP_modeleval.classificationReport(testing_y, custom_predictions)
print(custom_class_report_Multi)
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.87      0.73      0.79       307
#   Meningioma       0.71      0.72      0.71       271
#         None       0.88      0.97      0.92       255
#    Pituitary       0.89      0.93      0.91       367
#
#     accuracy                           0.84      1200
#    macro avg       0.84      0.84      0.84      1200
# weighted avg       0.84      0.84      0.84      1200

# %%
custom_class_report_Binary = FYP_modeleval.classificationReport(testing_y, custom_predictions, problem_type = "Binary")
print(custom_class_report_Binary)
custom_class_report_Binary_score = FYP_modeleval.calculateBinaryScore(custom_predictions, testing_y)
# Out:
#               precision    recall  f1-score   support
#
#       Tumour       0.99      0.96      0.98       945
#    No Tumour       0.88      0.97      0.92       255
#
#     accuracy                           0.97      1200
#    macro avg       0.94      0.97      0.95      1200
# weighted avg       0.97      0.97      0.97      1200
#
# Non-Rounded Binary Classification Score: 0.9658333333333333

# %%
custom_confusion_matrix_Multi = FYP_modeleval.plotConfusionMatrix(testing_y, custom_predictions)

# %%
custom_confusion_matrix_Binary = FYP_modeleval.plotConfusionMatrix(testing_y, custom_predictions, problem_type = "Binary")

# %%
custom_training_history = FYP_modeleval.plotTrainingHistory(Custom_Training_History)
# Out:
# Final Training Accuracy: 0.8312876224517822
#
# Final Validation Accuracy: 0.8379629850387573
#
# Final Training Loss: 0.4426153004169464
#
# Final Validation Loss: 0.41164833307266235
